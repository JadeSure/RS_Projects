# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.read_gml('./football.gml')
nx.draw(G,with_labels=True) 
plt.show() 
# show detail path from one vertex to another
print(nx.shortest_path(G, source='Buffalo', target='Kent'))
print(nx.shortest_path(G, source='Buffalo', target='Rice'))

# Dijkstra算法
# 'Buffalo'到其它路径节点的最小算法是如何计算的
# print(nx.single_source_dijkstra_path(G, 'Buffalo'))
print(nx.multi_source_dijkstra_path(G, {'Buffalo', 'Rice'}))
# Flody算法
# print(nx.floyd_warshall(G, weight='weight'))
# Out:
# ['Buffalo', 'Kent']
# ['Buffalo', 'BowlingGreenState', 'Michigan', 'Rice']
# {'Buffalo': ['Buffalo'], 'Rice': ['Rice'], 'NorthernIllinois': ['Buffalo', 'NorthernIllinois'], 'Akron': ['Buffalo', 'Akron'], 'BallState': ['Buffalo', 'BallState'], 'BowlingGreenState': ['Buffalo', 'BowlingGreenState'], 'Syracuse': ['Buffalo', 'Syracuse'], 'Connecticut': ['Buffalo', 'Connecticut'], 'Kent': ['Buffalo', 'Kent'], 'MiamiOhio': ['Buffalo', 'MiamiOhio'], 'Ohio': ['Buffalo', 'Ohio'], 'Rutgers': ['Buffalo', 'Rutgers'], 'Marshall': ['Buffalo', 'Marshall'], 'Michigan': ['Rice', 'Michigan'], 'FresnoState': ['Rice', 'FresnoState'], 'Houston': ['Rice', 'Houston'], 'SouthernMethodist': ['Rice', 'SouthernMethodist'], 'Nevada': ['Rice', 'Nevada'], 'SanJoseState': ['Rice', 'SanJoseState'], 'TexasElPaso': ['Rice', 'TexasElPaso'], 'Oklahoma': ['Rice', 'Oklahoma'], 'Tulsa': ['Rice', 'Tulsa'], 'TexasChristian': ['Rice', 'TexasChristian'], 'Hawaii': ['Rice', 'Hawaii'], 'Northwestern': ['Buffalo', 'NorthernIllinois', 'Northwestern'], 'WesternMichigan': ['Buffalo', 'NorthernIllinois', 'WesternMichigan'], 'Auburn': ['Buffalo', 'NorthernIllinois', 'Auburn'], 'CentralFlorida': ['Buffalo', 'NorthernIllinois', 'CentralFlorida'], 'CentralMichigan': ['Buffalo', 'NorthernIllinois', 'CentralMichigan'], 'EasternMichigan': ['Buffalo', 'NorthernIllinois', 'EasternMichigan'], 'Toledo': ['Buffalo', 'NorthernIllinois', 'Toledo'], 'VirginiaTech': ['Buffalo', 'Akron', 'VirginiaTech'], 'KansasState': ['Buffalo', 'BallState', 'KansasState'], 'Florida': ['Buffalo', 'BallState', 'Florida'], 'Pittsburgh': ['Buffalo', 'BowlingGreenState', 'Pittsburgh'], 'Temple': ['Buffalo', 'BowlingGreenState', 'Temple'], 'BrighamYoung': ['Buffalo', 'Syracuse', 'BrighamYoung'], 'BostonCollege': ['Buffalo', 'Syracuse', 'BostonCollege'], 'WestVirginia': ['Buffalo', 'Syracuse', 'WestVirginia'], 'EastCarolina': ['Buffalo', 'Syracuse', 'EastCarolina'], 'Cincinnati': ['Buffalo', 'Syracuse', 'Cincinnati'], 'MiamiFlorida': ['Buffalo', 'Syracuse', 'MiamiFlorida'], 'Louisville': ['Buffalo', 'Connecticut', 'Louisville'], 'MiddleTennesseeState': ['Buffalo', 'Connecticut', 'MiddleTennesseeState'], 'Purdue': ['Buffalo', 'Kent', 'Purdue'], 'OhioState': ['Buffalo', 'MiamiOhio', 'OhioState'], 'Vanderbilt': ['Buffalo', 'MiamiOhio', 'Vanderbilt'], 'Minnesota': ['Buffalo', 'Ohio', 'Minnesota'], 'IowaState': ['Buffalo', 'Ohio', 'IowaState'], 'Navy': ['Buffalo', 'Rutgers', 'Navy'], 'NotreDame': ['Buffalo', 'Rutgers', 'NotreDame'], 'NorthCarolina': ['Buffalo', 'Marshall', 'NorthCarolina'], 'MichiganState': ['Buffalo', 'Marshall', 'MichiganState'], 'PennState': ['Rice', 'Michigan', 'PennState'], 'Wisconsin': ['Rice', 'Michigan', 'Wisconsin'], 'UCLA': ['Rice', 'Michigan', 'UCLA'], 'Illinois': ['Rice', 'Michigan', 'Illinois'], 'Indiana': ['Rice', 'Michigan', 'Indiana'], 'California': ['Rice', 'FresnoState', 'California'], 'Memphis': ['Rice', 'Houston', 'Memphis'], 'SouthernMississippi': ['Rice', 'Houston', 'SouthernMississippi'], 'Tulane': ['Rice', 'Houston', 'Tulane'], 'Army': ['Rice', 'Houston', 'Army'], 'LouisianaState': ['Rice', 'Houston', 'LouisianaState'], 'Texas': ['Rice', 'Houston', 'Texas'], 'NorthCarolinaState': ['Rice', 'SouthernMethodist', 'NorthCarolinaState'], 'Kansas': ['Rice', 'SouthernMethodist', 'Kansas'], 'Wyoming': ['Rice', 'Nevada', 'Wyoming'], 'ColoradoState': ['Rice', 'Nevada', 'ColoradoState'], 'Oregon': ['Rice', 'Nevada', 'Oregon'], 'NevadaLasVegas': ['Rice', 'Nevada', 'NevadaLasVegas'], 'SouthernCalifornia': ['Rice', 'SanJoseState', 'SouthernCalifornia'], 'Nebraska': ['Rice', 'SanJoseState', 'Nebraska'], 'Stanford': ['Rice', 'SanJoseState', 'Stanford'], 'NewMexicoState': ['Rice', 'TexasElPaso', 'NewMexicoState'], 'TexasA&M': ['Rice', 'TexasElPaso', 'TexasA&M'], 'TexasTech': ['Rice', 'Oklahoma', 'TexasTech'], 'Baylor': ['Rice', 'Oklahoma', 'Baylor'], 'ArkansasState': ['Rice', 'Oklahoma', 'ArkansasState'], 'OklahomaState': ['Rice', 'Oklahoma', 'OklahomaState'], 'LouisianaTech': ['Rice', 'Tulsa', 'LouisianaTech'], 'Iowa': ['Buffalo', 'NorthernIllinois', 'Northwestern', 'Iow ...
