# %%
import networkx as nx
from networkx.algorithms import community
import matplotlib.pyplot as plt

# 数据加载
G=nx.read_gml('./football.gml')
# 可视化
nx.draw(G,with_labels=True) 
plt.show()
# 社区发现
# 标签传播
communities = list(community.label_propagation_communities(G))
print(communities)
print(len(communities))
# Out:
# [{'MiamiOhio', 'Kent', 'Ohio', 'Buffalo', 'BowlingGreenState', 'Akron', 'Connecticut', 'Marshall'}, {'Rutgers', 'MiamiFlorida', 'NotreDame', 'Navy', 'VirginiaTech', 'Pittsburgh', 'WestVirginia', 'Temple', 'BostonCollege', 'Syracuse'}, {'SanDiegoState', 'NewMexico', 'NevadaLasVegas', 'BrighamYoung', 'ColoradoState', 'Utah', 'Wyoming', 'AirForce'}, {'PennState', 'Wisconsin', 'Michigan', 'Minnesota', 'OhioState', 'Indiana', 'Northwestern', 'MichiganState', 'Purdue', 'Illinois', 'Iowa'}, {'KansasState', 'Kansas', 'Oklahoma', 'IowaState', 'Baylor', 'Missouri', 'Texas', 'TexasTech', 'Colorado', 'Nebraska', 'TexasA&M', 'OklahomaState'}, {'Virginia', 'WakeForest', 'Clemson', 'NorthCarolinaState', 'NorthCarolina', 'FloridaState', 'GeorgiaTech', 'Maryland', 'Duke'}, {'Arizona', 'UCLA', 'Washington', 'SouthernCalifornia', 'OregonState', 'California', 'Stanford', 'ArizonaState', 'NorthTexas', 'ArkansasState', 'BoiseState', 'Idaho', 'Oregon', 'UtahState', 'WashingtonState', 'NewMexicoState'}, {'Louisville', 'Tulane', 'Memphis', 'EastCarolina', 'Army', 'Cincinnati', 'SouthernMississippi', 'Houston', 'AlabamaBirmingham'}, {'LouisianaTech', 'Mississippi', 'Kentucky', 'LouisianaLafayette', 'Alabama', 'MississippiState', 'CentralFlorida', 'Tennessee', 'MiddleTennesseeState', 'LouisianaState', 'SouthCarolina', 'Vanderbilt', 'Florida', 'Georgia', 'Arkansas', 'Auburn', 'LouisianaMonroe'}, {'SanJoseState', 'SouthernMethodist', 'Rice', 'FresnoState', 'Nevada', 'Hawaii', 'Tulsa', 'TexasElPaso', 'TexasChristian'}, {'CentralMichigan', 'EasternMichigan', 'WesternMichigan', 'Toledo', 'NorthernIllinois', 'BallState'}]
# 11
